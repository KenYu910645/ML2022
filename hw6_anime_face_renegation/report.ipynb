# %%
# import pandas as pd 
from matplotlib import pyplot as plt 
import numpy as np
import pickle

# Load
with open('gnorm_list_c_1.0.pkl', 'rb') as f:
    gnorm_list_c_1 = pickle.load(f)
with open('gnorm_list_c_0.1.pkl', 'rb') as f:
    gnorm_list_c_2 = pickle.load(f)
with open('gnorm_list_c_0.01.pkl', 'rb') as f:
    gnorm_list_c_3 = pickle.load(f)
with open('gnorm_list_c_0.005.pkl', 'rb') as f:
    gnorm_list_c_4 = pickle.load(f)
# with open('gnorm_list_c_0.005.pkl', 'rb') as f:
#     gnorm_list_c_5 = pickle.load(f)
with open('gnorm_list_gp.pkl', 'rb') as f:
    gnorm_list_gp = pickle.load(f)

# fig = plt.figure(figsize=(20,10))
f, ax = plt.subplots(figsize=(20, 10))
t = np.arange(1,len(gnorm_list_c_1)+1)
# plt.plot(np.arange(1,len(gnorm_list_c_1)+1), np.array(gnorm_list_c_1))
plt.plot(t, np.array(gnorm_list_c_2))
plt.plot(t, np.array(gnorm_list_c_3))
plt.plot(t, np.array(gnorm_list_gp))
# plt.plot(t, np.array(gnorm_list_c_4))
ax.invert_xaxis()
# plt.plot(np.arange(1,len(gnorm_list_c_1)+1), np.array(gnorm_list_c_5))
plt.rcParams.update({'font.size': 28})

plt.legend(['c=0.1', 'c=0.01', 'gradient penalty'])
plt.xlabel('Discriminator Layer')
plt.ylabel('Gradient Norm (Log Scale)')
# plt.title("gnorm")
plt.show()
